# %%
list1 = ["apple", "mango", "banana", "orange"]
list2 = ["tomato", "potato", "carrot", "radish"]

# %%
list1=["apple", "mango", "banana", "orange"]
list2=["tomato", "potato", "carrot", "radish"]
list1.append("grapes")
list2.append("cucumber")
